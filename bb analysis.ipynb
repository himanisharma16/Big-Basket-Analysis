# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# STEP 1:
# LOAD DATASET

# %%
data = pd.read_csv("C:\\Users\\Himani Sharma\\OneDrive\\Desktop\\projects skillcircle\\BigBasket Products.csv")

# %%
data
# Out:
#        index                                            product  \
# 0          1             Garlic Oil - Vegetarian Capsule 500 mg
# 1          2                              Water Bottle - Orange
# 2          3                     Brass Angle Deep - Plain, No.2
# 3          4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4          5                 Creme Soft Soap - For Hands & Body
# ...      ...                                                ...
# 27550  27551         Wottagirl! Perfume Spray - Heaven, Classic
# 27551  27552                                           Rosemary
# 27552  27553                       Peri-Peri Sweet Potato Chips
# 27553  27554                          Green Tea - Pure Original
# 27554  27555                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# ...

# %% [markdown]
# Step 2: Use head function to look for first 12 rows.

# %%
data.head(12)
# Out:
#     index                                            product  \
# 0       1             Garlic Oil - Vegetarian Capsule 500 mg
# 1       2                              Water Bottle - Orange
# 2       3                     Brass Angle Deep - Plain, No.2
# 3       4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4       5                 Creme Soft Soap - For Hands & Body
# 5       6                  Germ - Removal Multipurpose Wipes
# 6       7                                       Multani Mati
# 7       8                  Hand Sanitizer - 70% Alcohol Base
# 8       9  Biotin & Collagen Volumizing Hair Shampoo + Bi...
# 9      10               Scrub Pad - Anti- Bacterial, Regular
# 10     11                           Wheat Grass Powder - Raw
# 11     12                     Butter Cookies Gold Collection
#
#                   category            sub_category              brand  \
# 0         Beauty & Hygiene               Hair Care  Sri Sri Ayurveda
# ...

# %% [markdown]
# Step 3: Get Description of the data in the DataFrame.

# %%
data.describe().T
# Out:
#                 count          mean          std   min     25%       50%  \
# index         27555.0  13778.000000  7954.587670  1.00  6889.5  13778.00
# sale_price    27549.0    334.648391  1202.102113  2.45    95.0    190.32
# market_price  27555.0    382.056664   581.730717  3.00   100.0    220.00
# rating        18919.0      3.943295     0.739217  1.00     3.7      4.10
#
#                   75%       max
# index         20666.5   27555.0
# sale_price      359.0  112475.0
# market_price    425.0   12500.0
# rating            4.3       5.0

# %% [markdown]
# Step 4: Find Information about the DataFrame.

# %%
data.shape
# Out:
# (27555, 10)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27555 entries, 0 to 27554
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   index         27555 non-null  int64
#  1   product       27554 non-null  object
#  2   category      27555 non-null  object
#  3   sub_category  27555 non-null  object
#  4   brand         27554 non-null  object
#  5   sale_price    27549 non-null  float64
#  6   market_price  27555 non-null  float64
#  7   type          27555 non-null  object
#  8   rating        18919 non-null  float64
#  9   description   27440 non-null  object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 2.1+ MB

# %% [markdown]
# Step 5: Find out Top & least sold products.

# %%
top_products = data['product'].value_counts().head(5)
least_products = data['product'].value_counts().tail(5)
print("Top 5 Products:", top_products)
print("Least 5 Products:", least_products)
# Out:
# Top 5 Products: product
# Turmeric Powder/Arisina Pudi          26
# Extra Virgin Olive Oil                15
# Cow Ghee/Tuppa                        14
# Soft Drink                            12
# Colorsilk Hair Colour With Keratin    12
# Name: count, dtype: int64
# Least 5 Products: product
# Pepper & Herb Salami Chicken                                     1
# Nutmeg Powder                                                    1
# Disney Mickey Mouse Plastic Kids Sipper Bottle - Coolest Dude    1
# Chocolates-Roasted Peanut Chocolate                              1
# Green Tea - Pure Original                                        1
# Name: count, dtype: int64

# %% [markdown]
# Step 6: Measuring discount on a certain item.

# %%
# Measuring discount on a certain item
discount=data["market_price"]-data["sale_price"]
discount=round(discount/data["market_price"]*100,2)

discount_df = pd.DataFrame({"Product": data["product"],"Discount (%)": discount})
print(discount_df)
# Out:
#                                                  Product  Discount (%)
# 0                 Garlic Oil - Vegetarian Capsule 500 mg          0.00
# 1                                  Water Bottle - Orange          0.00
# 2                         Brass Angle Deep - Plain, No.2         52.40
# 3      Cereal Flip Lid Container/Storage Jar - Assort...         15.34
# 4                     Creme Soft Soap - For Hands & Body          0.00
# ...                                                  ...           ...
# 27550         Wottagirl! Perfume Spray - Heaven, Classic         20.00
# 27551                                           Rosemary         10.00
# 27552                       Peri-Peri Sweet Potato Chips          0.00
# 27553                          Green Tea - Pure Original         20.00
# 27554                     United Dreams Go Far Deodorant         44.99
#
# [27555 rows x 2 columns]

# %% [markdown]
# Step 7: Find out the Missing Values from the Dataset.

# %%
data.isnull().sum()
# Out:
# index              0
# product            1
# category           0
# sub_category       0
# brand              1
# sale_price         6
# market_price       0
# type               0
# rating          8636
# description      115
# dtype: int64

# %%
#percentage of missing values 
round((data.isnull().sum()/(len(data)))*100,2)
# Out:
# index            0.00
# product          0.00
# category         0.00
# sub_category     0.00
# brand            0.00
# sale_price       0.02
# market_price     0.00
# type             0.00
# rating          31.34
# description      0.42
# dtype: float64

# %%
#Data Reduction
data = data.drop(['index'], axis = 1)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27555 entries, 0 to 27554
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product       27554 non-null  object
#  1   category      27555 non-null  object
#  2   sub_category  27555 non-null  object
#  3   brand         27554 non-null  object
#  4   sale_price    27549 non-null  float64
#  5   market_price  27555 non-null  float64
#  6   type          27555 non-null  object
#  7   rating        18919 non-null  float64
#  8   description   27440 non-null  object
# dtypes: float64(3), object(6)
# memory usage: 1.9+ MB

# %%
# column rating has high percentage of missing values therefore it is better to drop
data=data.drop(columns=['rating'],errors='ignore')

# %%
#imputing for missing values
#for numeric columns
data['sale_price']=data['sale_price'].fillna(data['sale_price'].median())

# %%
#missing value in categorical column
data=data.dropna(subset=['product','brand'])

# %%
# handling null value in description with "No Description"
data['description']=data['description'].fillna('No Description')

# %%
data.isnull().sum()
# Out:
# product         0
# category        0
# sub_category    0
# brand           0
# sale_price      0
# market_price    0
# type            0
# description     0
# dtype: int64

# %% [raw]
# now we have handled all the null values with imputing and droppping values.

# %% [markdown]
# Step 8: Find out the outliers from the dataset according to the columns and fill them with the mean.

# %%
# column 'sale_price'
Q1 = data['sale_price'].quantile(0.25)
Q3 = data['sale_price'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Replace outliers with mean
data['sale_price'] = np.where(
    (data['sale_price'] < lower_bound) | (data['sale_price'] > upper_bound),data['sale_price'].mean(),data['sale_price'])

# %%
# column 'market_price'
Q1 = data['market_price'].quantile(0.25)
Q3 = data['market_price'].quantile(0.75)
IQR = Q3 - Q1
lower_bound_m = Q1 - 1.5 * IQR
upper_bound_m = Q3 + 1.5 * IQR

# Replace outliers with mean
data['market_price'] = np.where(
    (data['market_price'] < lower_bound) | (data['market_price'] > upper_bound),data['market_price'].mean(),data['market_price'])

# %% [markdown]
# Step 9: Create Plots or visualizations.

# %%
# Scatter plot for Sale Price vs Market Price
plt.figure(figsize=(8, 6))
sns.scatterplot(x='sale_price', y='market_price', data=data)
plt.title('Sale Price vs Market Price')
plt.xlabel('Sale Price')
plt.ylabel('Market Price')
plt.show()

# %%
# Box plot for numerical column 'Sale Price' vs categorical column 'Category'
plt.figure(figsize=(8, 6))
sns.boxplot(x='category', y='sale_price', data=data)
plt.title('Sale Price Distribution by Category')
plt.xlabel('Category')
plt.ylabel('Sale Price')
plt.xticks(rotation=45)
plt.show()

# %%
# top 10 most costly brand according to sale price
plt.subplots(figsize=(12,7))
data.groupby('brand')['sale_price'].sum().nlargest(10).sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='brand'>

# %%
sns.set(rc={"figure.figsize": (20, 7)})

if 'category' in data.columns and not data['category'].isnull().all():
    ax = sns.countplot(data=data, x="category")
    
    
    for bars in ax.containers:
        ax.bar_label(bars, fmt='%d')  
    
    
    plt.xticks(rotation=90)
    
    
    plt.title("Count of Each Category", fontsize=16)
    plt.xlabel("Category", fontsize=14)
    plt.ylabel("Count", fontsize=14)
    
    
    plt.show()
else:
    print("Column 'category' is missing or has no valid data!")
